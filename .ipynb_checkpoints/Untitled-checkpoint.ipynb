# %%
import networkx as nx
from node2vec import Node2Vec

# %%
# Create a graph
graph = nx.fast_gnp_random_graph(n=50, p=0.1)

nx.draw_networkx(graph, with_labels=False, node_size=50, node_color='r')
